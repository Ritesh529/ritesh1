# %%
def myfunc1(x,y):
    l1=[]
    for i in range(x,y):
        if(i%7 == 0) and (i%5 != 0) :
            l1.append(str(i))
    print(','.join(l1))
            
            
myfunc1(2000,3200)
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %%
fname=(input("Enter First name:"))
lname=(input("Enter last name:"))

def reverse(s):
    return s[-1::-1]

print(reverse(lname)+' '+reverse(fname))
# Out:
# Enter First name:david
# Enter last name:boon
# noob divad

# %%
values =[int(i) for i in input().split()]
print(values)
# Out:
# 1 23 5 6
# [1, 23, 5, 6]

# %%
n=6
for i in range(n):
    print(i*"*")
for i in range(n-1):
    print((n-i)*"*")
print("*")
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *****
# ****
# ***
# **
# *

# %% [markdown]
# # <font color="blue"><h2>Machine Learning</h2></font>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data =pd.read_csv(r'E:\alldata.csv')
data.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
data1 =pd.read_csv(r'E:\alldata.csv',index_col =['position'])
rows  = data1.loc[["Data Analyst","Data Scientist","Machine Learning","Big Data"]]
#print(type(rows))
rows
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#                                     company  \
# position
# Data Analyst                 Operation HOPE
# Data Analyst           Applied Systems Inc.
# Data Analyst                     TrueMotion
# Data Analyst               Uptown Treehouse
# Data Analyst                     Amazon.com
# Data Analyst                        Panjiva
# Data Analyst          DEPARTMENT OF FINANCE
# Data Analyst                 Bowery Farming
# Data Analyst                     Source One
# Data Analyst       WeWork Global Technology
# Data Analyst                      Schireson
# Data Analyst                       Dashlane
# ...

# %%
data2 = pd.read_csv(r'E:\alldata.csv',usecols=['company'])
dd=data2['company'].unique()
print(len(dd))  #<!--------Find the total number of companies---------->
# Out:
# 2214

# %%
data3 = pd.read_csv(r'E:\alldata.csv')
data3.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA

# %%
data4 = pd.read_csv(r'E:\alldata.csv',usecols=['position'])
print(len(data4))
# Out:
# 6964

# %%
dd = data4['position'].unique()
print(len(dd))
# Out:
# 5243

# %%
data5 =pd.read_csv(r'E:\alldata.csv',index_col =['company'])
rows1  = data5.loc[["ALS TDI"]]
rows1
#print(len(rows1))
# Out:
#                                                 position  \
# company
# ALS TDI                             Development Director
# ALS TDI                 Stewardship and Data Coordinator
# ALS TDI                               Director of Events
# ALS TDI  Associate Scientist I/II Translational Research
# ALS TDI               Director of Fundraising and Events
#
#                                                description  reviews  \
# company
# ALS TDI  Development Director\nALS Therapy Development ...      NaN
# ALS TDI  Stewardship &amp; Data Coordinator\nThe ALS Th...      NaN
# ALS TDI  We are seeking a full-time Director of Events ...      NaN
# ALS TDI  Associate Scientist I/II Translational Researc...      NaN
# ALS TDI  Director of Fundraising and Events\nWe are see...      NaN
#
#                     location
# company
# ALS TDI   Atlanta, GA 30301
# ALS TDI  Cambridge, MA 02139
# ALS TDI  Cambridge, MA 02139
# ALS TDI  Cambridge, MA 02139
# ALS TDI  Cambridge, MA 02139

# %%
data6 =pd.read_csv(r'E:\alldata.csv')
