# %%
import pandas as pd
data = pd.read_csv(r'E:\Match.csv')
data
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
df1 = data[data.match_winner == 'Mumbai Indians']
df1
# Out:
#      Match_SK  match_id                        Team1  \
# 15         15    336002        Kolkata Knight Riders
# 22         22    336009               Mumbai Indians
# 26         26    336013               Mumbai Indians
# 30         30    336017  Royal Challengers Bangalore
# 36         36    336023               Mumbai Indians
# 39         39    336026               Mumbai Indians
# 42         42    336029              Deccan Chargers
# 58         58    392186          Chennai Super Kings
# 72         72    392202        Kolkata Knight Riders
# 78         78    392208        Kolkata Knight Riders
# 93         93    392223  Royal Challengers Bangalore
# 97         97    392227              Kings XI Punjab
# 116       116    419112               Mumbai Indians
# 123       123    419119             Delhi Daredevils
# 131       131    419127               Mumbai Indians
# 134       134    419130               Mumbai Indians
# 139       139    419135              Deccan Chargers
# ...

# %%
Team = []
l = data.match_winner
for i in l :
    Team.append(i)
Team
# Out:
# ['Kolkata Knight Riders',
#  'Chennai Super Kings',
#  'Delhi Daredevils',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Kings XI Punjab',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Deccan Chargers',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Mumbai Indians',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Royal Challengers Bangalore',
#  'Kings XI Punjab',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Kings XI Punjab',
#  'Deccan Chargers',
#  'Mumbai Indians',
#  'Chennai Super Kings',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Mumbai Indians',
#  'Chennai Super Kings',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Mumbai Indians',
#  'Kings XI Punjab',
# ...

# %%
Year = []
m = data.Season_Year
for i in m :
    Year.append(i)
Year
# Out:
# [2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2008,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
#  2009,
# ...

# %%
df = data.Team1.unique()
da = (len(df))
print(da)
df[3]
# Out:
# 13
# 'Mumbai Indians'

# %%
df = data.Team1.unique()
da = (len(df))
print(da)
a=df[0]


ds = data.Season_Year.unique()
db = (len(ds))
print(db)
b=ds[1]

for k in range(0,len(df)):
    da = data[(data.Season_Year == ds[0]) & (data.match_winner == df[0])] 
    lenth = len(da)


print("No of matches won by ",df[0],"in",ds[0],"is:" ,lenth)
print("No of matches won by ",df[1],"in",ds[0],"is:" ,lenth1)
print("No of matches won by ",df[2],"in",ds[0],"is:" ,lenth2)
# Out:
# 13
# 10
# No of matches won by  Royal Challengers Bangalore in 2008 is: 4
# No of matches won by  Kings XI Punjab in 2008 is: 10
# No of matches won by  Delhi Daredevils in 2008 is: 7

# %%
dg = data[(data.Season_Year == 2008) & (data.match_winner == 'Mumbai Indians')] 
dg
# Out:
#     Match_SK  match_id                        Team1                  Team2  \
# 15        15    336002        Kolkata Knight Riders         Mumbai Indians
# 22        22    336009               Mumbai Indians       Delhi Daredevils
# 26        26    336013               Mumbai Indians       Rajasthan Royals
# 30        30    336017  Royal Challengers Bangalore         Mumbai Indians
# 36        36    336023               Mumbai Indians    Chennai Super Kings
# 39        39    336026               Mumbai Indians  Kolkata Knight Riders
# 42        42    336029              Deccan Chargers         Mumbai Indians
#
#     match_date  Season_Year                                 Venue_Name  \
# 15   4/29/2008         2008                               Eden Gardens
# 22  05-04-2008         2008                 Dr DY Patil Sports Academy
# 26  05-07-2008         2008                 Dr DY Patil Sports Academy
# 30   5/28/2008         2008                      M Chinnaswamy Stadium
# ...

# %%
da = data[(data.Season_Year == 2008) & (data.match_winner == 'Mumbai Indians')] 
lenth = len(da)
print("No of matches won by ",a,"in",b,"is:" ,lenth)
# Out:
# No of matches won by  Mumbai Indians in 2008 is: 7

# %%
Year = []
m = data.Season_Year
n = m.unique()
#n
for i in n :
    Year.append(i)
print(Year)

#for i in range(0,10) :
 #   print(Year[i])
# Out:
# [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
#Print no. of matches won by each team based on year wise (each year as one column)
import numpy as np
import pandas

df1=pandas.read_csv('E:\Match.csv',usecols=['Season_Year']) #reading the data with particular column
years=np.unique(df1.values)             #print unique years present in the data

df2=pandas.read_csv('E:\Match.csv',usecols=['Team1'])  #reading the data with particular column
teams=np.unique(df2.values)             #print unique teams present in the data

df5=pandas.DataFrame()
df5['teams']=teams           #print the teams column which consists of the unique teams

df3=pandas.read_csv('E:\Match.csv',usecols=['match_winner']) #print the total match winners in the data

for x in years:      #range of years
    a=[]
    for j in teams:       #range of teams
        count=0
        for i in range(len(df3)):  #giving total winners as range
            if j==df3.values[i] and df1.values[i]==x:  #iterates and takes assign the teams to df3 and year to df1
                count=count+1     #count gets increases and appended to a list which is then assigned to df5 teams coln
        a.append(count)
    df5[x]=a
print(df5)
# Out:
#                           teams  2008  2009  2010  2011  2012  2013  2014  \
# 0           Chennai Super Kings     9     8     9    11    10    12    10
# 1               Deccan Chargers     2     9     8     6     4     0     0
# 2              Delhi Daredevils     7    10     7     4    11     3     2
# 3                 Gujarat Lions     0     0     0     0     0     0     0
# 4               Kings XI Punjab    10     7     4     7     8     8    12
# 5          Kochi Tuskers Kerala     0     0     0     6     0     0     0
# 6         Kolkata Knight Riders     6     3     7     8    12     6    11
# 7                Mumbai Indians     7     5    11    10    10    13     7
# 8                 Pune Warriors     0     0     0     4     4     4     0
# 9              Rajasthan Royals    13     6     6     6     7    11     7
# 10      Rising Pune Supergiants     0     0     0     0     0     0     0
# 11  Royal Challengers Bangalore     4     9     8    10     8     9     5
# ...

# %%
#Print  ManOfMach count of each player in  Hyderabad stadium
import numpy as np
list1=[]
count=0
a =data[(data.City_Name == 'Hyderabad')]
for i in a.ManOfMach :
    list1.append(i)
#list1
aa = np.unique(list1)
emp=[]
#list1.count('A Mishra')
for i in aa :
    q=list1.count(i)
    emp.append(q)
g = dict(zip(aa,emp))
g
# Out:
# {'A Mishra': 2,
#  'AB Dinda': 1,
#  'AT Rayudu': 1,
#  'B Kumar': 1,
#  'CH Morris': 1,
#  'DA Warner': 6,
#  'DJ Bravo': 1,
#  'DJG Sammy': 1,
#  'DW Steyn': 3,
#  'G Gambhir': 1,
#  'GH Vihari': 2,
#  'I Sharma': 1,
#  'MJ McClenaghan': 1,
#  'MR Marsh': 1,
#  'Mandeep Singh': 1,
#  'Mustafizur Rahman': 1,
#  'PA Patel': 1,
#  'PC Valthaty': 1,
#  'R Vinay Kumar': 1,
#  'SC Ganguly': 1,
#  'SE Marsh': 1,
#  'SK Raina': 2,
#  'SK Trivedi': 1,
#  'SL Malinga': 1,
#  'UT Yadav': 1,
#  'V Kohli': 1,
#  'V Sehwag': 2,
#  'WP Saha': 1,
#  'YK Pathan': 2}

# %%
 #Print number of matches won and loss(as two columns). 
#Consider as win when a team wins Toss  and Match . print for each and every team

import pandas,numpy
#f=pandas.read_csv('DataFiles/Match.csv')
#teams=numpy.unique(f.Team1)
df=pandas.DataFrame()
df['teams']=xx
ab=[]
bc=[]
for x in xx:
    win=loss=0
    for i in range(len(f)):
        if x==f.Toss_Winner[i] and x==f.match_winner[i]:
            win=win+1
        elif x==f.Toss_Winner[i] or x==f.match_winner[i]:
            loss=loss+1
    ab.append(win)
    bc.append(loss)
df['win']=ab
df['loss']=bc
df
