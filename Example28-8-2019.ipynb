# %%
#Example:
import pandas as pd
data=pd.DataFrame({'PlayerName' : ['Dhawan','Rohit','Kohli','Rahul','Dhoni','Kedar','Jadeja','Pant','Pandya','Kuldeep','Chahal','Kumar','Shami','Bumrah'],
                   'Role' : ['Batsmen','Batsmen','Batsmen','Batsmen','Wk-Batsmen','All-rounder','All-rounder','Wk-Batsmen','All-rounder','Bowler','Bowler','Bowler','Bowler','Bowler'],
                   'Player_Style' : ['Left-hand Batsmen','Right-hand Batsmen',None,'Right-hand Batsmen','Right-hand Batsmen','Right-hand Batsmen','Left-hand Batsmen','Left-hand Batsmen','Right-hand Batsmen','Left-hand Batsmen','Right-hand Batsmen','Right-hand Batsmen','Right-hand Batsmen','Right-hand Batsmen'],
                   'Score' : [5500,7100,10210,2780,10150,1850,3210,1600,2100,800,300,1500,600,33],
                   'JerseyNo' : [25,None,18,99,7,64,48,15,66,40,11,91,77,33] 
                  })
data
# Out:
#    PlayerName         Role        Player_Style  Score  JerseyNo
# 0      Dhawan      Batsmen   Left-hand Batsmen   5500      25.0
# 1       Rohit      Batsmen  Right-hand Batsmen   7100       NaN
# 2       Kohli      Batsmen                None  10210      18.0
# 3       Rahul      Batsmen  Right-hand Batsmen   2780      99.0
# 4       Dhoni   Wk-Batsmen  Right-hand Batsmen  10150       7.0
# 5       Kedar  All-rounder  Right-hand Batsmen   1850      64.0
# 6      Jadeja  All-rounder   Left-hand Batsmen   3210      48.0
# 7        Pant   Wk-Batsmen   Left-hand Batsmen   1600      15.0
# 8      Pandya  All-rounder  Right-hand Batsmen   2100      66.0
# 9     Kuldeep       Bowler   Left-hand Batsmen    800      40.0
# 10     Chahal       Bowler  Right-hand Batsmen    300      11.0
# 11      Kumar       Bowler  Right-hand Batsmen   1500      91.0
# 12      Shami       Bowler  Right-hand Batsmen    600      77.0
# 13     Bumrah       Bowler  Right-hand Batsmen     33      33.0

# %%
data = data.dropna()     # Drop the rows with 'nan' or 'none' values 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 13
# Data columns (total 5 columns):
# PlayerName      12 non-null object
# Role            12 non-null object
# Player_Style    12 non-null object
# Score           12 non-null int64
# JerseyNo        12 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 576.0+ bytes

# %%
data = data.astype({"PlayerName":'category', "Score":'float64'}) 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 13
# Data columns (total 5 columns):
# PlayerName      12 non-null category
# Role            12 non-null object
# Player_Style    12 non-null object
# Score           12 non-null float64
# JerseyNo        12 non-null float64
# dtypes: category(1), float64(2), object(2)
# memory usage: 908.0+ bytes

# %%
data
# Out:
#    PlayerName         Role        Player_Style  Score  JerseyNo
# 0      Dhawan      Batsmen   Left-hand Batsmen   5500      25.0
# 1       Rohit      Batsmen  Right-hand Batsmen   7100       NaN
# 2       Kohli      Batsmen                None  10210      18.0
# 3       Rahul      Batsmen  Right-hand Batsmen   2780      99.0
# 4       Dhoni   Wk-Batsmen  Right-hand Batsmen  10150       7.0
# 5       Kedar  All-rounder  Right-hand Batsmen   1850      64.0
# 6      Jadeja  All-rounder   Left-hand Batsmen   3210      48.0
# 7        Pant   Wk-Batsmen   Left-hand Batsmen   1600      15.0
# 8      Pandya  All-rounder  Right-hand Batsmen   2100      66.0
# 9     Kuldeep       Bowler   Left-hand Batsmen    800      40.0
# 10     Chahal       Bowler  Right-hand Batsmen    300      11.0
# 11      Kumar       Bowler  Right-hand Batsmen   1500      91.0
# 12      Shami       Bowler  Right-hand Batsmen    600      77.0
# 13     Bumrah       Bowler  Right-hand Batsmen     33      33.0

# %%
#Example for pandas series unique()
array = data["Role"].unique() 
print(array)
# Out:
# ['Batsmen' 'Wk-Batsmen' 'All-rounder' 'Bowler']

# %%
#Example for pandas series nunique()
data.nunique(axis = 0)
# Out:
# PlayerName      12
# Role             4
# Player_Style     2
# Score           12
# JerseyNo        12
# dtype: int64

# %%
data.nunique(axis = 1)
# Out:
# 0     5
# 1     4
# 2     4
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    4
# dtype: int64

# %%
#Example 2:
data
# Out:
#    PlayerName         Role        Player_Style  Score  JerseyNo
# 0      Dhawan      Batsmen   Left-hand Batsmen   5500      25.0
# 1       Rohit      Batsmen  Right-hand Batsmen   7100       NaN
# 2       Kohli      Batsmen                None  10210      18.0
# 3       Rahul      Batsmen  Right-hand Batsmen   2780      99.0
# 4       Dhoni   Wk-Batsmen  Right-hand Batsmen  10150       7.0
# 5       Kedar  All-rounder  Right-hand Batsmen   1850      64.0
# 6      Jadeja  All-rounder   Left-hand Batsmen   3210      48.0
# 7        Pant   Wk-Batsmen   Left-hand Batsmen   1600      15.0
# 8      Pandya  All-rounder  Right-hand Batsmen   2100      66.0
# 9     Kuldeep       Bowler   Left-hand Batsmen    800      40.0
# 10     Chahal       Bowler  Right-hand Batsmen    300      11.0
# 11      Kumar       Bowler  Right-hand Batsmen   1500      91.0
# 12      Shami       Bowler  Right-hand Batsmen    600      77.0
# 13     Bumrah       Bowler  Right-hand Batsmen     33      33.0

# %%
data.nunique(axis = 0, dropna = True)
# Out:
# PlayerName      14
# Role             4
# Player_Style     2
# Score           14
# JerseyNo        13
# dtype: int64

# %%
#Example for pandas dataframe select_dstype()
data
# Out:
#    PlayerName         Role        Player_Style  Score  JerseyNo
# 0      Dhawan      Batsmen   Left-hand Batsmen   5500      25.0
# 1       Rohit      Batsmen  Right-hand Batsmen   7100       NaN
# 2       Kohli      Batsmen                None  10210      18.0
# 3       Rahul      Batsmen  Right-hand Batsmen   2780      99.0
# 4       Dhoni   Wk-Batsmen  Right-hand Batsmen  10150       7.0
# 5       Kedar  All-rounder  Right-hand Batsmen   1850      64.0
# 6      Jadeja  All-rounder   Left-hand Batsmen   3210      48.0
# 7        Pant   Wk-Batsmen   Left-hand Batsmen   1600      15.0
# 8      Pandya  All-rounder  Right-hand Batsmen   2100      66.0
# 9     Kuldeep       Bowler   Left-hand Batsmen    800      40.0
# 10     Chahal       Bowler  Right-hand Batsmen    300      11.0
# 11      Kumar       Bowler  Right-hand Batsmen   1500      91.0
# 12      Shami       Bowler  Right-hand Batsmen    600      77.0
# 13     Bumrah       Bowler  Right-hand Batsmen     33      33.0

# %%
data.select_dtypes(include ='float64')
# Out:
#     JerseyNo
# 0       25.0
# 1        NaN
# 2       18.0
# 3       99.0
# 4        7.0
# 5       64.0
# 6       48.0
# 7       15.0
# 8       66.0
# 9       40.0
# 10      11.0
# 11      91.0
# 12      77.0
# 13      33.0

# %%
data.select_dtypes(exclude ='float64')
# Out:
#    PlayerName         Role        Player_Style  Score
# 0      Dhawan      Batsmen   Left-hand Batsmen   5500
# 1       Rohit      Batsmen  Right-hand Batsmen   7100
# 2       Kohli      Batsmen                None  10210
# 3       Rahul      Batsmen  Right-hand Batsmen   2780
# 4       Dhoni   Wk-Batsmen  Right-hand Batsmen  10150
# 5       Kedar  All-rounder  Right-hand Batsmen   1850
# 6      Jadeja  All-rounder   Left-hand Batsmen   3210
# 7        Pant   Wk-Batsmen   Left-hand Batsmen   1600
# 8      Pandya  All-rounder  Right-hand Batsmen   2100
# 9     Kuldeep       Bowler   Left-hand Batsmen    800
# 10     Chahal       Bowler  Right-hand Batsmen    300
# 11      Kumar       Bowler  Right-hand Batsmen   1500
# 12      Shami       Bowler  Right-hand Batsmen    600
# 13     Bumrah       Bowler  Right-hand Batsmen     33

# %%
#Example for pandas dataframe append()
import pandas as pd 
df1 = pd.DataFrame({"a":['A','B','C','D'], 
                         "b":[1, 2, 3, 4]}) 
df2 = pd.DataFrame({"a":['E', 'F', 'G'], 
                    "b":[5, 6, 7]}) 
print(df1, "\n") 
df2
# Out:
#    a  b
# 0  A  1
# 1  B  2
# 2  C  3
# 3  D  4
#    a  b
# 0  E  5
# 1  F  6
# 2  G  7

# %%
#Now appending df2 at the end of df1.
df1.append(df2)
# Out:
#    a  b
# 0  A  1
# 1  B  2
# 2  C  3
# 3  D  4
# 0  E  5
# 1  F  6
# 2  G  7

# %%
#Continous index numbers
df1.append(df2, ignore_index = True)
# Out:
#    a  b
# 0  A  1
# 1  B  2
# 2  C  3
# 3  D  4
# 4  E  5
# 5  F  6
# 6  G  7

# %%
#Example 2:
import pandas as pd 
df1 = pd.DataFrame({"a":['A','B','C','D'], 
                         "b":[1, 2, 3, 4]}) 
df2 = pd.DataFrame({"a":['E', 'F', 'G'], 
                    "b":[5, 6, 7],
                    "c":[101,102,103]}) 
print(df1, "\n") 
df2
# Out:
#    a  b
# 0  A  1
# 1  B  2
# 2  C  3
# 3  D  4
#    a  b    c
# 0  E  5  101
# 1  F  6  102
# 2  G  7  103

# %%
df1.append(df2, ignore_index = True)
# Out:
#    a  b      c
# 0  A  1    NaN
# 1  B  2    NaN
# 2  C  3    NaN
# 3  D  4    NaN
# 4  E  5  101.0
# 5  F  6  102.0
# 6  G  7  103.0

# %%
df1.append(df2, ignore_index = False)
# Out:
#    a  b      c
# 0  A  1    NaN
# 1  B  2    NaN
# 2  C  3    NaN
# 3  D  4    NaN
# 0  E  5  101.0
# 1  F  6  102.0
# 2  G  7  103.0

# %%
#astype() example 1:
import pandas as pd

data=pd.read_excel(r'C:\Users\admin\Documents\nba.xlsx')
data
# Out:
#          Name           Team   Number Position  Age  Height  Weight   \
# 0     Bradley  Boston Ceitics       0       PG   30    6.20    180.0
# 1        Tony  Boston Ceitics      90       SG   23    5.80    196.0
# 2   John Rude  Boston Ceitics      45       SF   29    6.00    210.0
# 3       Kelly  Boston Ceitics      90       SG   28    6.30    205.0
# 4       Jonas  Boston Ceitics      65       PF   26    5.90    182.0
# 5       Hamus  Boston Ceitics      32       PF   31    6.10    192.3
# 6     Johnson  Boston Ceitics      45        C   29    5.50    169.5
# 7        Tery  Boston Ceitics      85       PG   23    5.80    175.6
# 8      Marcus  Boston Ceitics      46       SF   28    5.60    186.5
# 9        Amir  Boston Ceitics      71       SG   24    6.20    200.5
# 10     Jordan  Boston Ceitics      21       PF   27    6.00    194.3
# 11     Thomas  Boston Ceitics      43       SG   23    6.10    189.6
# 12     Hunter  Boston Ceitics      52       SG   22    5.70    187.4
# ...

# %%
#astype() example 2:
data[:10]
# Out:
#         Name           Team   Number Position  Age  Height  Weight   \
# 0    Bradley  Boston Ceitics       0       PG   30     6.2    180.0
# 1       Tony  Boston Ceitics      90       SG   23     5.8    196.0
# 2  John Rude  Boston Ceitics      45       SF   29     6.0    210.0
# 3      Kelly  Boston Ceitics      90       SG   28     6.3    205.0
# 4      Jonas  Boston Ceitics      65       PF   26     5.9    182.0
# 5      Hamus  Boston Ceitics      32       PF   31     6.1    192.3
# 6    Johnson  Boston Ceitics      45        C   29     5.5    169.5
# 7       Tery  Boston Ceitics      85       PG   23     5.8    175.6
# 8     Marcus  Boston Ceitics      46       SF   28     5.6    186.5
# 9       Amir  Boston Ceitics      71       SG   24     6.2    200.5
#
#           College    Salary
# 0           Texas  775123.0
# 1      Louisville  458136.0
# 2       Marquette       NaN
# 3             LSU  145632.0
# 4  Oklahama State  456124.0
# 5       Marquette  815426.0
# ...

# %%
#astype() example 3:
data.dropna(inplace=True)
data
# Out:
#         Name           Team   Number Position  Age  Height  Weight   \
# 0    Bradley  Boston Ceitics       0       PG   30    6.20    180.0
# 1       Tony  Boston Ceitics      90       SG   23    5.80    196.0
# 3      Kelly  Boston Ceitics      90       SG   28    6.30    205.0
# 4      Jonas  Boston Ceitics      65       PF   26    5.90    182.0
# 5      Hamus  Boston Ceitics      32       PF   31    6.10    192.3
# 7       Tery  Boston Ceitics      85       PG   23    5.80    175.6
# 8     Marcus  Boston Ceitics      46       SF   28    5.60    186.5
# 9       Amir  Boston Ceitics      71       SG   24    6.20    200.5
# 10    Jordan  Boston Ceitics      21       PF   27    6.00    194.3
# 11    Thomas  Boston Ceitics      43       SG   23    6.10    189.6
# 12    Hunter  Boston Ceitics      52       SG   22    5.70    187.4
# 13     Sally  Boston Ceitics      46       PF   26    5.10    196.6
# 14  morrison  Boston Ceitics      74        C   23    5.60    179.5
# ...

# %%
#astype() example 4:
before=type(data.Number[0])
print(before)
data.Number=data.Number.astype('float64')
after = type(data.Number[0]) 
print(after)
# Out:
# <class 'numpy.int64'>
# <class 'numpy.float64'>

# %%
data
# Out:
#          Name           Team   Number Position  Age  Height  Weight   \
# 0     Bradley  Boston Ceitics     0.0       PG   30    6.20    180.0
# 1        Tony  Boston Ceitics    90.0       SG   23    5.80    196.0
# 2   John Rude  Boston Ceitics    45.0       SF   29    6.00    210.0
# 3       Kelly  Boston Ceitics    90.0       SG   28    6.30    205.0
# 4       Jonas  Boston Ceitics    65.0       PF   26    5.90    182.0
# 5       Hamus  Boston Ceitics    32.0       PF   31    6.10    192.3
# 6     Johnson  Boston Ceitics    45.0        C   29    5.50    169.5
# 7        Tery  Boston Ceitics    85.0       PG   23    5.80    175.6
# 8      Marcus  Boston Ceitics    46.0       SF   28    5.60    186.5
# 9        Amir  Boston Ceitics    71.0       SG   24    6.20    200.5
# 10     Jordan  Boston Ceitics    21.0       PF   27    6.00    194.3
# 11     Thomas  Boston Ceitics    43.0       SG   23    6.10    189.6
# 12     Hunter  Boston Ceitics    52.0       SG   22    5.70    187.4
# ...

# %%
#astype() example 5:
data=data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 18
# Data columns (total 9 columns):
# Name        17 non-null object
# Team        17 non-null object
# Number      17 non-null float64
# Position    17 non-null object
# Age         17 non-null int64
# Height      17 non-null float64
# Weight      17 non-null float64
# College     17 non-null object
# Salary      17 non-null float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.3+ KB

# %%
#astype() example 6:
data=data.astype({"Name":'category',"Age":'int32'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 18
# Data columns (total 9 columns):
# Name        17 non-null category
# Team        17 non-null object
# Number      17 non-null float64
# Position    17 non-null object
# Age         17 non-null int32
# Height      17 non-null float64
# Weight      17 non-null float64
# College     17 non-null object
# Salary      17 non-null float64
# dtypes: category(1), float64(4), int32(1), object(3)
# memory usage: 1.9+ KB

# %%
#Example for unique function 1:
import pandas as pd
data=pd.read_excel(r'C:\Users\admin\Documents\nba.xlsx')
data
# Out:
#          Name           Team   Number Position  Age  Height  Weight   \
# 0     Bradley  Boston Ceitics       0       PG   30    6.20    180.0
# 1        Tony  Boston Ceitics      90       SG   23    5.80    196.0
# 2   John Rude  Boston Ceitics      45       SF   29    6.00    210.0
# 3       Kelly  Boston Ceitics      90       SG   28    6.30    205.0
# 4       Jonas  Boston Ceitics      65       PF   26    5.90    182.0
# 5       Hamus  Boston Ceitics      32       PF   31    6.10    192.3
# 6     Johnson  Boston Ceitics      45        C   29    5.50    169.5
# 7        Tery  Boston Ceitics      85       PG   23    5.80    175.6
# 8      Marcus  Boston Ceitics      46       SF   28    5.60    186.5
# 9        Amir  Boston Ceitics      71       SG   24    6.20    200.5
# 10     Jordan  Boston Ceitics      21       PF   27    6.00    194.3
# 11     Thomas  Boston Ceitics      43       SG   23    6.10    189.6
# 12     Hunter  Boston Ceitics      52       SG   22    5.70    187.4
# ...

# %%
#Example for unique function 2:
array=data["Position"].unique()
print(array)
# Out:
# ['PG' 'SG' 'SF' 'PF' 'C']

# %%
#Example for unique function 3:
array=data["College"].unique()
print(array)
# Out:
# ['Texas' 'Louisville' 'Marquette' 'LSU' 'Oklahama State' nan 'Gonzaga']

# %%
#Example for nunique function 1:
import pandas as pd 
data=pd.DataFrame({
    "A" : [14,5,4,1,4],
    "B" : [5,2,50,3,2],
    "C" : [20,20,7,3,8],
    "D" : [14,3,6,2,6]
})
data
# Out:
#     A   B   C   D
# 0  14   5  20  14
# 1   5   2  20   3
# 2   4  50   7   6
# 3   1   3   3   2
# 4   4   2   8   6

# %%
data.nunique(axis=0)
# Out:
# A    4
# B    4
# C    4
# D    4
# dtype: int64

# %%
#Excercise:1
import pandas as pd
data=pd.read_csv(r'E:\AppleStore.csv')
data
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 11     284815117                                   SCRABBLE Premium
# 12     284815942               Google – Search made just for mobile
# ...

# %%
def unique_apps():
        #array=data["track_name"].unique()
        #print(len(array))
        #return array
    list1=list()
    for i in data.track_name:
        if i not in list1:
            list1.append(i)
    print(len(list1))    
    return list1

print("total number of unique apps from the dataset",unique_apps())
# Out:
# 7195
# ...

# %%
df=data.rating_count_tot
df
# Out:
# 0         21292
# 1        161065
# 2        188583
# 3        262241
# 4        985920
# 5          8253
# 6        119487
# 7       1126879
# 8          1117
# 9          7885
# 10        76720
# 11       105776
# 12       479440
# 13       119773
# 14         6340
# 15        56194
# 16      2974676
# 17       223885
# 18       402925
# 19        31456
# 20         2929
# 21        11447
# 22       137951
# 23            8
# 24         3241
# 25         5795
# 26        42316
# 27       123215
# 28          782
# 29         3449
#          ...
# 7167          1
# 7168          3
# 7169          9
# 7170         39
# 7171         10
# 7172         55
# 7173          0
# 7174         14
# 7175         41
# 7176          0
# 7177         11
# 7178          0
# 7179        279
# 7180         26
# 7181          0
# 7182          0
# 7183        292
# 7184          0
# 7185          0
# 7186          1
# 7187         23
# 7188         18
# 7189          0
# 7190         97
# ...

# %%
def no_of_downloads():
    #dd=data.nlargest(10,['rating_count_tot'])
    #df=dd.rating_count_tot
    #return df
    
    df=data.rating_count_tot
    list1=[]
    for i in df:
        list1.append(i)
    list1.sort(reverse=True) 
    for x in range(10):
        print(list1[x])
    
    
print(no_of_downloads())
# Out:
# 2974676
# 2161558
# 2130805
# 1724546
# 1126879
# 1061624
# 985920
# 961794
# 878563
# 824451
# None

# %%
df=data.cont_rating
df
# Out:
# 0        4+
# 1        4+
# 2        4+
# 3       12+
# 4        4+
# 5        4+
# 6        4+
# 7       12+
# 8        4+
# 9        4+
# 10       4+
# 11       4+
# 12      17+
# 13       4+
# 14       4+
# 15       4+
# 16       4+
# 17      12+
# 18      12+
# 19       4+
# 20       4+
# 21       4+
# 22       4+
# 23       4+
# 24       4+
# 25       4+
# 26       9+
# 27       4+
# 28       4+
# 29       4+
#        ...
# 7167     4+
# 7168     4+
# 7169     4+
# 7170     9+
# 7171     4+
# 7172     4+
# 7173     4+
# 7174     4+
# 7175     4+
# 7176     4+
# 7177     4+
# 7178     4+
# 7179     4+
# 7180     9+
# 7181     9+
# 7182     4+
# 7183     9+
# 7184     9+
# 7185     9+
# 7186     4+
# 7187     4+
# 7188    12+
# 7189     9+
# 7190     4+
# 7191    17+
# 7192     4+
# 7193     4+
# 7194     9+
# 7195    12+
# 7196     4+
# Name: cont_rating, Length: 7197, dtype: object

# %%
def no_of_cont():
    df=data.cont_rating
    #print(dd)
    #print(df[dd].value_counts())
    #count=data['cont_rating'].value_counts()
    
    count1=0
    count2=0
    count3=0
    count4=0
    
   
    for i in df:
        if i == '4+':
            count1+=1
        elif i == '9+':
            count2+=1
        elif i == '12+':
            count3+=1
        elif i == '17+':
            count4+=1
        else:
            pass
    w.append(count1)
    w.append(count2)
    w.append(count3)
    w.append(count4)
    print("Number of apps with content rating 4+",count1)
    print("Number of apps with content rating 9+",count2)
    print("Number of apps with content rating 12+",count3)
    print("Number of apps with content rating 17+",count4)

w=[]
print(no_of_cont())
w
# Out:
# Number of apps with content rating 4+ 4433
# Number of apps with content rating 9+ 987
# Number of apps with content rating 12+ 1155
# Number of apps with content rating 17+ 622
# None
# [4433, 987, 1155, 622]

# %%
import matplotlib.pyplot as plt

all_apps = ['4+','9+','12+','17+']
labels=list(all_apps)

plt.pie(w, labels =labels, explode = [0.1,0,0,0], shadow = True , startangle = 90 ,autopct = '%1.1f%%', labeldistance = 1.2)
plt.legend(loc = "best")

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
a=['free','paid']
x = data[data.prime_genre == 'Sports']
data=0
count=0
l=[]
#print(x.price)
for i in x.price:
    if i == 0.0 :
        data+=1
    else:
        count+=1
l.append(data)
l.append(count)
#print(l)
index=np.arange(len(a))
plt.bar(a,l,width=0.7,color="b")
# Out:
# <BarContainer object of 2 artists>

# %%
import random
df = pd.DataFrame()
df['Mark'] = [ random.randint(0,101)  for k in range(51)]

print(df)
# Out:
#     Mark
# 0     68
# 1     77
# 2     71
# 3     43
# 4     61
# 5      6
# 6     39
# 7     58
# 8     46
# 9    100
# 10    23
# 11    72
# 12    19
# 13    61
# 14    57
# 15    29
# 16    28
# 17    75
# 18    84
# 19    85
# 20    29
# 21    19
# 22    84
# 23    90
# 24    49
# 25    89
# 26    33
# 27     0
# 28    47
# 29    31
# 30    78
# 31    39
# 32    97
# 33    53
# 34    21
# 35    80
# 36    85
# 37     0
# 38    40
# 39    64
# 40    55
# 41     4
# 42    69
# 43    80
# 44    36
# 45    16
# 46    52
# 47    65
# 48    53
# 49    50
# 50    70

# %%
#Using the Matplotlib library, generate a Pie Chart to categorise student marks data in a CSV file 
#into Distinction, First Class, Second Class, Third Class and Failed Categories(based on percentages). Explode the Distinction category.
#1.Generate a CSV containing marks of 2000 students

import pandas as pd
data=pd.read_csv(r'E:\Student_Data.csv')
data
# Out:
#     Percentage
# 0           68
# 1           77
# 2           71
# 3           43
# 4           61
# 5            6
# 6           39
# 7           58
# 8           46
# 9          100
# 10          23
# 11          72
# 12          19
# 13          61
# 14          57
# 15          29
# 16          28
# 17          75
# 18          84
# 19          85
# 20          29
# 21          19
# 22          84
# 23          90
# 24          49
# 25          89
# 26          33
# 27           0
# 28          47
# 29          31
# 30          78
# 31          39
# 32          97
# 33          53
# 34          21
# 35          80
# 36          85
# 37           0
# 38          40
# 39          64
# 40          55
# 41           4
# 42          69
# 43          80
# 44          36
# 45          16
# 46          52
# 47          65
# 48          53
# 49          50
# 50          70

# %%
print(data.Percentage)
# Out:
# 0      68
# 1      77
# 2      71
# 3      43
# 4      61
# 5       6
# 6      39
# 7      58
# 8      46
# 9     100
# 10     23
# 11     72
# 12     19
# 13     61
# 14     57
# 15     29
# 16     28
# 17     75
# 18     84
# 19     85
# 20     29
# 21     19
# 22     84
# 23     90
# 24     49
# 25     89
# 26     33
# 27      0
# 28     47
# 29     31
# 30     78
# 31     39
# 32     97
# 33     53
# 34     21
# 35     80
# 36     85
# 37      0
# 38     40
# 39     64
# 40     55
# 41      4
# 42     69
# 43     80
# 44     36
# 45     16
# 46     52
# 47     65
# 48     53
# 49     50
# 50     70
# Name: Percentage, dtype: int64

# %%
r=[]
r.append(data.Percentage)
r
# Out:
# [0      68
#  1      77
#  2      71
#  3      43
#  4      61
#  5       6
#  6      39
#  7      58
#  8      46
#  9     100
#  10     23
#  11     72
#  12     19
#  13     61
#  14     57
#  15     29
#  16     28
#  17     75
#  18     84
#  19     85
#  20     29
#  21     19
#  22     84
#  23     90
#  24     49
#  25     89
#  26     33
#  27      0
#  28     47
#  29     31
#  30     78
#  31     39
#  32     97
#  33     53
#  34     21
#  35     80
#  36     85
#  37      0
#  38     40
#  39     64
#  40     55
#  41      4
#  42     69
#  43     80
#  44     36
#  45     16
#  46     52
#  47     65
#  48     53
#  49     50
#  50     70
#  Name: Percentage, dtype: int64]

# %%
labels=list(marks)
marks = ['Distinction', 'First Class', 'Second Class', 'Third Class' , 'Failed']
plt.pie(r, labels =labels,explode = [0.1,0,0,0,0], shadow = True , startangle = 90 ,autopct = '%1.1f%%', labeldistance = 1.2)
plt.legend(loc = "best")
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-69d9414c2a0f> in <module>
#       1 labels=list(marks)
#       2 marks = ['Distinction', 'First Class', 'Second Class', 'Third Class' , 'Failed']
# ----> 3 plt.pie(r, labels =labels,explode = [0.1,0,0,0,0], shadow = True , startangle = 90 ,autopct = '%1.1f%%', labeldistance = 1.2)
#       4 plt.legend(loc = "best")
#
# ...
